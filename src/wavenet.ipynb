# %%
import dill

# %%
dill.load_session('notebook_env.db')
# Out:
# music21: Certain music21 functions might need the optional package matplotlib;
#                   if you run into errors, install it by following the instructions at
#                   http://mit.edu/music21/doc/installing/installAdditional.html
# Using TensorFlow backend.
# c:\users\murta\onedrive\documents\sp 20\dl (615)\project\deep-learning-project\env\lib\site-packages\tensorflow\python\framework\indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
from music21 import *
import os, numpy as np
# Out:
# music21: Certain music21 functions might need the optional package matplotlib;
#                   if you run into errors, install it by following the instructions at
#                   http://mit.edu/music21/doc/installing/installAdditional.html

# %%
def read_midi(file):
    
#     print("Loading Music File:",file)
    
    notes=[]
    notes_to_parse = None
    
    #parsing a midi file
    midi = converter.parse(file)
    
    #grouping based on different instruments
    s2 = instrument.partitionByInstrument(midi)
    
    #Looping over all the instruments
    if s2 is not None:
        for part in s2.parts:
            #select elements of only piano
            if 'Piano' in str(part): 
                
                notes_to_parse = part.recurse() 
                
                #finding whether a particular element is note or a chord
                for element in notes_to_parse:
                    print(element)
                    #note
                    if isinstance(element, note.Note):
                        notes.append(str(element.pitch))
                    
                    #chord
                    elif isinstance(element, chord.Chord):
                        notes.append('.'.join(str(n) for n in element.normalOrder))

    return np.array(notes)

# %%
#specify the path
path= os.getcwd() + "\\..\\data\\lmd_full\\1\\"

#read all the filenames
files=[i for i in os.listdir(path) if i.endswith(".mid")]

#reading each midi file
notes_list = []
i = 0
while (i < 50):
    try:
        notes_list.append(read_midi(path + files[i]))
        i += 1
        print(i)
    except:
        pass
# notes_array = np.array([read_midi(path+i) for i in files])
notes_array = np.array(notes_list)
print(len(notes_array))

#converting 2D array into 1D array
notes_ = [element for note_ in notes_array for element in note_]

#No. of unique notes
unique_notes = list(set(notes_))
print(len(unique_notes))
# Out:
# 1
# 2
# 3
# Piano
# <music21.tempo.MetronomeMark allegro moderato Quarter=130.0>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# <music21.tempo.MetronomeMark allegro moderato Quarter=130.0>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# C major
# <music21.meter.TimeSignature 4/4>
# <music21.note.Note A>
# <music21.note.Rest rest>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Rest rest>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.tempo.MetronomeMark allegro moderato Quarter=130.0>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.tempo.MetronomeMark allegro moderato Quarter=130.0>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.tempo.MetronomeMark allegro moderato Quarter=130.0>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.tempo.MetronomeMark allegro moderato Quarter=130.0>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note G#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note E>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note G#>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note E->
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.tempo.MetronomeMark allegro moderato Quarter=129.96>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note G#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note E>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note G#>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note E->
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note E->
# <music21.note.Note E->
# <music21.note.Note C#>
# <music21.note.Note F>
# <music21.note.Note E->
# <music21.note.Note C>
# <music21.note.Note F>
# <music21.note.Note F#>
# <music21.note.Note E->
# <music21.note.Note F>
# <music21.note.Note E->
# <music21.note.Note F>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note E->
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note B>
# <music21.note.Note F>
# <music21.note.Note D>
# <music21.note.Note B->
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note D>
# <music21.note.Note F>
# <music21.note.Note D>
# <music21.note.Note F>
# <music21.note.Note E->
# <music21.note.Note E->
# <music21.note.Note C#>
# <music21.note.Note F>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note B->
# <music21.note.Note F#>
# <music21.note.Note E->
# <music21.note.Note F>
# <music21.note.Note F#>
# <music21.note.Note B->
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note E->
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note B>
# <music21.note.Note F>
# <music21.note.Note F#>
# <music21.note.Note B->
# <music21.note.Note D>
# <music21.note.Note F>
# <music21.note.Note D>
# <music21.note.Note F>
# <music21.note.Note F#>
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note G#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note E>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note A>
# <music21.note.Note C#>
# <music21.note.Note C>
# <music21.note.Note C#>
# <music21.note.Note G#>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note E->
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note D>
# <music21.note.Note G>
# <music21.note.Note F#>
# <music21.note.Note G>
# <music21.note.Note F#>
# <music21.note.Note B->
# <music21.note.Note B>
# <music21.note.Note D>
# <music21.note.Note B->
# <music21.note.Note A>
# <music21.note.Note F#>
# <music21.note.Note D>
# <music21.note.Note F#>
# <music21.note.Note G>
# <music21.note.Note B->
# <music21.note.Note B>
# <music21.note.Note B->
# <music21.note.Note A>
# <music21.note.Note C>
# <music21.note.Note G>
# <music21.note.Note E->
# <music21.note.Note G#>
# <music21.note.Note G>
# <music21.note.Note G#>
# <music21.note.Note G>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note E->
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note G>
# <music21.note.Note E->
# <music21.note.Note G>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C#>
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note C#>
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note C#>
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note C#>
# <music21.note.Note D>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C#>
# <music21.note.Note D>
# <music21.note.Note G#>
# <music21.note.Note B>
# <music21.note.Note C#>
# <music21.note.Note D>
# <music21.note.Note G#>
# <music21.note.Note C#>
# <music21.note.Note E->
# <music21.note.Note E>
# <music21.note.Note B>
# <music21.note.Note C#>
# <music21.note.Note E->
# <music21.note.Note E>
# <music21.note.Note B>
# <music21.note.Note C#>
# <music21.note.Note E->
# <music21.note.Note E>
# <music21.note.Note B>
# <music21.note.Note C#>
# <music21.note.Note E->
# <music21.note.Note E>
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Note C#>
# <music21.note.Note E->
# <music21.note.Note E>
# <music21.note.Note B->
# <music21.note.Note C#>
# <music21.note.Note E->
# <music21.note.Note E>
# <music21.note.Note B->
# 4
# Piano
# <music21.tempo.MetronomeMark moderate Quarter=92.02>
# E- major
# <music21.meter.TimeSignature 4/4>
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# 5
# Piano
# <music21.tempo.MetronomeMark larghetto Quarter=60.0>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord E-4 C4 G3 C2>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord E-4 C4 G3 C2>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord C2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note G>
# <music21.note.Note F>
# <music21.note.Note C>
# <music21.note.Note E->
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord E-4 C4 G3 C2>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord C2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note G>
# <music21.note.Note F>
# <music21.note.Note C>
# <music21.note.Note E->
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord E-4 C4 G3 C2>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord C2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note G#>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note G#>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord E-4 C4 G3 C2>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord C2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G#>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note G#>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note E->
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord E-4 C4 G3 C2 C5>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord C2 C2 F#2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note G>
# <music21.note.Note F>
# <music21.note.Note F#>
# <music21.note.Note E->
# <music21.note.Note E>
# <music21.chord.Chord C2 C2 F#2>
# <music21.chord.Chord E-4 C4 G3 C2 G4>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.chord.Chord C2 C2 F#2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note G>
# <music21.note.Note F>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note E->
# <music21.note.Note C>
# <music21.chord.Chord C2 C2 F#2>
# <music21.chord.Chord E-4 C4 G3 C2>
# <music21.note.Note G>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note C>
# <music21.note.Note B->
# <music21.chord.Chord C2 C2 F#2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note G#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note G#>
# <music21.note.Note E>
# <music21.chord.Chord C2 C2 F#2>
# <music21.chord.Chord E-4 C4 G3 C2 G#4>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.chord.Chord E2 F#2>
# <music21.chord.Chord E2 B-2>
# <music21.note.Note E>
# <music21.chord.Chord C2 C2 F#2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G#>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note G#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note E->
# <music21.note.Note C>
# <music21.chord.Chord C2 C2 F#2>
# <music21.chord.Chord E-4 C4 G3 C2 C5>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note B->
# <music21.chord.Chord C2 C2 F#2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note G>
# <music21.note.Note F>
# <music21.note.Note F#>
# <music21.note.Note E->
# <music21.note.Note E>
# <music21.chord.Chord C2 C2 F#2>
# <music21.chord.Chord E-4 C4 G3 C2 G3>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.chord.Chord C2 C2 F#2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note G>
# <music21.note.Note F>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note E->
# <music21.note.Note C>
# <music21.chord.Chord C2 C2 F#2>
# <music21.chord.Chord E-4 C4 G3 C2 G3>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note C>
# <music21.note.Note B->
# <music21.chord.Chord C2 C2 F#2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note G#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note G#>
# <music21.note.Note E>
# <music21.chord.Chord C2 C2 F#2>
# <music21.chord.Chord E-4 C4 G3 C2 G#3>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.chord.Chord E2 F#2>
# <music21.chord.Chord E2 B-2>
# <music21.note.Note E>
# <music21.chord.Chord C2 C2 F#2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G#>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note G#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note E->
# <music21.note.Note C>
# <music21.chord.Chord C2 C2 F#2>
# <music21.chord.Chord E-4 C4 G3 C2 C4>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord C5 E2 F#2>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.note.Note F#>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2>
# <music21.chord.Chord E2 F#2>
# <music21.note.Note B->
# <music21.chord.Chord C2 C2 F#2 E3>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note E>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord C5 E2 F#2 A5>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord F#2 A5>
# <music21.note.Note C>
# <music21.chord.Chord F#2 G#5>
# <music21.note.Note E>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord E2 F#2 A5>
# <music21.note.Note E->
# <music21.note.Note D>
# <music21.chord.Chord F#2 G#5>
# <music21.note.Note C>
# <music21.chord.Chord E2 G#5>
# <music21.chord.Chord C2 C2 F#2 A5>
# <music21.chord.Chord E-4 C4 G3 C2>
# <music21.note.Note E->
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord C5 E2 F#2 A5>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord F#2 A5>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord E2 F#2 A5>
# <music21.chord.Chord E2 F#2 G#5>
# <music21.chord.Chord E2 G#5>
# <music21.note.Note E>
# <music21.chord.Chord C2 C2 F#2 E3 A5>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note E>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord C5 E2 F#2 A5>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord F#2 A5>
# <music21.note.Note C>
# <music21.chord.Chord F#2 G#5>
# <music21.note.Note E>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord E2 F#2 A5>
# <music21.note.Note E->
# <music21.note.Note D>
# <music21.chord.Chord E2 F#2 G#5>
# <music21.note.Note C>
# <music21.note.Note G#>
# <music21.chord.Chord C2 C2 F#2 A5>
# <music21.chord.Chord E-4 C4 G3 C2 E-4>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord C5 E2 F#2 A5>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord F#2 A5>
# <music21.note.Note C>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord E2 F#2 A5>
# <music21.note.Note C>
# <music21.chord.Chord E2 F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.note.Note B->
# <music21.chord.Chord C2 C2 F#2 E3 A5>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note E>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord C5 E2 F#2 A5>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord F#2 A5>
# <music21.note.Note C>
# <music21.chord.Chord F#2 G#5>
# <music21.note.Note E>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord E2 F#2 A5>
# <music21.note.Note E->
# <music21.note.Note D>
# <music21.chord.Chord F#2 G#5>
# <music21.note.Note C>
# <music21.chord.Chord E2 G#5>
# <music21.chord.Chord C2 C2 F#2 A5>
# <music21.chord.Chord E-4 C4 G3 C2>
# <music21.note.Note E->
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord C5 E2 F#2 A5>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord F#2 A5>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord E2 F#2 A5>
# <music21.chord.Chord E2 F#2 G#5>
# <music21.note.Note G>
# <music21.chord.Chord E2 B-2 G#5>
# <music21.note.Note E>
# <music21.chord.Chord C2 C2 F#2 E3 A5>
# <music21.chord.Chord D4 C4 G#3 C2>
# <music21.note.Note G>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord C5 E2 F#2 A5>
# <music21.chord.Chord F#2 G#5>
# <music21.note.Note G>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord F#2 A5>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord E2 F#2 A5>
# <music21.note.Note B>
# <music21.chord.Chord E2 F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord C2 C2 F#2 A5>
# <music21.chord.Chord E-4 C4 G3 C2 C4>
# <music21.note.Rest rest>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord C5 E2 F#2 A5>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord F#2 A5>
# <music21.note.Note C>
# <music21.chord.Chord F#2 G#5>
# <music21.chord.Chord C2 G#5>
# <music21.chord.Chord E2 F#2 A5>
# <music21.chord.Chord E2 F#2 G#5>
# <music21.note.Note B->
# <music21.note.Note F#>
# <music21.note.Rest rest>
# 6
# Piano
# <music21.note.Rest rest>
# <music21.chord.Chord D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.note.Note A>
# <music21.note.Rest rest>
# <music21.note.Note A>
# <music21.note.Rest rest>
# <music21.note.Note A>
# <music21.note.Rest rest>
# <music21.note.Note F>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 C2>
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.chord.Chord B-2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 C2>
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.chord.Chord B-2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 D2>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.chord.Chord A3 D2>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 D2>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 C#3 A2>
# <music21.note.Rest rest>
# <music21.chord.Chord B-2 C2>
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.chord.Chord A3 D2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 D2>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note A>
# <music21.note.Rest rest>
# <music21.note.Note A>
# <music21.note.Rest rest>
# <music21.note.Note A>
# <music21.note.Rest rest>
# <music21.note.Note F>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 A3 D2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 C3 C#3>
# <music21.note.Rest rest>
# <music21.note.Note A>
# <music21.note.Rest rest>
# <music21.note.Note A>
# <music21.note.Rest rest>
# <music21.chord.Chord B1 A3>
# <music21.note.Rest rest>
# <music21.note.Note F>
# <music21.note.Rest rest>
# <music21.note.Note F>
# <music21.note.Rest rest>
# <music21.chord.Chord C3 C#3 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C3>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2 A2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 A2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note F>
# <music21.note.Rest rest>
# <music21.note.Note F>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord B-2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 A3>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord B-2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 A3>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 B-2>
# <music21.note.Rest rest>
# <music21.note.Note E->
# <music21.note.Rest rest>
# <music21.chord.Chord C2 B-2>
# <music21.note.Rest rest>
# <music21.note.Note E->
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note E->
# <music21.note.Rest rest>
# <music21.chord.Chord C2 B-2>
# <music21.note.Rest rest>
# <music21.note.Note E->
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.note.Note E->
# <music21.note.Rest rest>
# <music21.chord.Chord C2 B-2>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 B-2>
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.chord.Chord C2 B-2>
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.chord.Chord C2 B-2>
# <music21.note.Rest rest>
# <music21.note.Note B->
# <music21.note.Rest rest>
# <music21.chord.Chord C2 B-2>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 E2>
# <music21.note.Rest rest>
# <music21.note.Note E>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 E2>
# <music21.note.Rest rest>
# <music21.chord.Chord E2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord B-2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord B-2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord B-2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2 A2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 F2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C#3 A2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 F2>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 C#3 F2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 F2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 F2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 F2>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 C#3 F2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 F2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 F2 D2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 D2>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 C#3 D2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 D2>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 D2>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note C#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C#3 D2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note C#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C#3 D2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note C#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C2>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 C#3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C#3 D2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C#3 D2>
# <music21.note.Rest rest>
# <music21.note.Note D>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 C#3 F2>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.note.Note C>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 D2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 D2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 D2 C#3>
# <music21.note.Rest rest>
# <music21.chord.Chord C#3 C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 A3 D2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord G#2 D2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord C2 G#2>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# <music21.chord.Chord D2 G#2 A3>
# <music21.note.Rest rest>
# <music21.note.Note G#>
# <music21.note.Rest rest>
# ...
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note C#>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.chord.Chord G2 B1>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note F>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.note.Note B->
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.note.Note B->
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.note.Note B->
# <music21.chord.Chord D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.note.Note B->
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.note.Note B->
# <music21.note.Note B>
# <music21.chord.Chord B-2 C3 B1>
# <music21.note.Note B>
# <music21.chord.Chord A2 B1>
# <music21.note.Note B->
# <music21.chord.Chord D2 B1>
# <music21.chord.Chord B-2 C3 B1>
# <music21.note.Note B>
# <music21.chord.Chord C3 B1>
# <music21.note.Note A>
# <music21.chord.Chord G2 B1>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note F>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.note.Note B->
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord C3 B1>
# <music21.note.Note B>
# <music21.chord.Chord G2 B1>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.chord.Chord C3 B1>
# <music21.chord.Chord A2 B1>
# <music21.chord.Chord G2 B1>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord C3 B1>
# <music21.chord.Chord A2 B1>
# <music21.chord.Chord B2 B1>
# <music21.chord.Chord A2 B1>
# <music21.chord.Chord G2 B1>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.chord.Chord C3 B1>
# <music21.chord.Chord A2 B1>
# <music21.chord.Chord G2 B1>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 E2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord C3 B1>
# <music21.chord.Chord A2 B1>
# <music21.chord.Chord B2 B1>
# <music21.chord.Chord A2 B1>
# <music21.chord.Chord G2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note G>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B->
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 G3 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 C3 B1>
# <music21.chord.Chord B2 B1>
# <music21.chord.Chord B-2 A2 B1>
# <music21.chord.Chord G2 B1>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 G3 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 C3 B1>
# <music21.chord.Chord B2 B1>
# <music21.chord.Chord B-2 B1>
# <music21.chord.Chord C3 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 G3 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 G3 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 G3 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 C3 B1>
# <music21.chord.Chord B2 B1>
# <music21.chord.Chord B-2 A2 B1>
# <music21.chord.Chord G2 B1>
# <music21.chord.Chord B-2 F2 B1>
# <music21.note.Note B>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.chord.Chord B-2 D2 B1>
# <music21.note.Note C#>
# 50
# 50
# 396

# %%
len(notes_array)
# Out:
# 50

# %%
from collections import Counter

#computing frequency of each note
freq = dict(Counter(notes_))

frequent_notes = [note_ for note_, count in freq.items() if count>=50]
print(len(frequent_notes))
# Out:
# 99

# %%
new_music=[]

for notes in notes_array:
    temp=[]
    for note_ in notes:
        if note_ in frequent_notes:
            temp.append(note_)            
    new_music.append(temp)
    
new_music = np.array(new_music)

new_music = notes_array

# %%
no_of_timesteps = 32
x = []
y = []

for note_ in new_music:
    for i in range(0, len(note_) - no_of_timesteps, 1):
        
        #preparing input and output sequences
        input_ = note_[i:i + no_of_timesteps]
        output = note_[i + no_of_timesteps]
        
        x.append(input_)
        y.append(output)
        
x=np.array(x)
y=np.array(y)

# %%
unique_x = list(set(x.ravel()))
x_note_to_int = dict((note_, number) for number, note_ in enumerate(unique_x))

# %%
x_seq=[]
for i in x:
    temp=[]
    for j in i:
        #assigning unique integer to every note
        temp.append(x_note_to_int[j])
    x_seq.append(temp)
    
x_seq = np.array(x_seq)

# %%
unique_y = list(set(y))
y_note_to_int = dict((note_, number) for number, note_ in enumerate(unique_y)) 
y_seq=np.array([y_note_to_int[i] for i in y])

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(x_seq,y_seq,test_size=0.2,random_state=0)

# %%
from keras.layers import *
from keras.models import *
from keras.callbacks import *
import keras.backend as K

K.clear_session()
model = Sequential()
    
#embedding layer
model.add(Embedding(len(unique_x), 100, input_length=32,trainable=True)) 

model.add(Conv1D(64,3, padding='causal',activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))
    
model.add(Conv1D(128,3,activation='relu',dilation_rate=2,padding='causal'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))

model.add(Conv1D(256,3,activation='relu',dilation_rate=4,padding='causal'))
model.add(Dropout(0.2))
model.add(MaxPool1D(2))
          
#model.add(Conv1D(256,5,activation='relu'))    
model.add(GlobalMaxPool1D())
    
model.add(Dense(256, activation='relu'))
model.add(Dense(len(unique_y), activation='softmax'))
    
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

model.summary()
# Out:
# Using TensorFlow backend.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 32, 100)           39500
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 32, 64)            19264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 64)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 16, 64)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 16, 128)           24704
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 128)           0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 8, 128)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 8, 256)            98560
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 256)            0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 4, 256)            0
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 396)               101772
# =================================================================
# Total params: 349,592
# Trainable params: 349,592
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc=ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True,verbose=1)

# %%
history = model.fit(np.array(x_tr),np.array(y_tr),batch_size=128,epochs=50, validation_data=(np.array(x_val),np.array(y_val)),verbose=1, callbacks=[mc])
# Out:
# c:\users\murta\onedrive\documents\sp 20\dl (615)\project\deep-learning-project\env\lib\site-packages\tensorflow\python\framework\indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 21128 samples, validate on 5282 samples
# Epoch 1/50
# 21128/21128 [==============================] - 13s 594us/step - loss: 3.8295 - val_loss: 3.3194
#
# Epoch 00001: val_loss improved from inf to 3.31940, saving model to best_model.h5
# Epoch 2/50
# 21128/21128 [==============================] - 13s 604us/step - loss: 2.9211 - val_loss: 2.9527
#
# Epoch 00002: val_loss improved from 3.31940 to 2.95274, saving model to best_model.h5
# Epoch 3/50
# 21128/21128 [==============================] - 13s 597us/step - loss: 2.6489 - val_loss: 2.8723
#
# Epoch 00003: val_loss improved from 2.95274 to 2.87226, saving model to best_model.h5
# Epoch 4/50
# 21128/21128 [==============================] - 13s 607us/step - loss: 2.4966 - val_loss: 2.6739
#
# Epoch 00004: val_loss improved from 2.87226 to 2.67385, saving model to best_model.h5
# Epoch 5/50
# 21128/21128 [==============================] - 13s 602us/step - loss: 2.3783 - val_loss: 2.5720
#
# Epoch 00005: val_loss improved from 2.67385 to 2.57204, saving model to best_model.h5
# Epoch 6/50
# 21128/21128 [==============================] - 13s 606us/step - loss: 2.2960 - val_loss: 2.5383
#
# Epoch 00006: val_loss improved from 2.57204 to 2.53829, saving model to best_model.h5
# Epoch 7/50
# 21128/21128 [==============================] - 13s 603us/step - loss: 2.2125 - val_loss: 2.4402
#
# Epoch 00007: val_loss improved from 2.53829 to 2.44021, saving model to best_model.h5
# Epoch 8/50
# 21128/21128 [==============================] - 13s 606us/step - loss: 2.1453 - val_loss: 2.3900
#
# Epoch 00008: val_loss improved from 2.44021 to 2.39002, saving model to best_model.h5
# Epoch 9/50
# 21128/21128 [==============================] - 13s 605us/step - loss: 2.0801 - val_loss: 2.3492
#
# Epoch 00009: val_loss improved from 2.39002 to 2.34917, saving model to best_model.h5
# Epoch 10/50
# 21128/21128 [==============================] - 13s 606us/step - loss: 2.0180 - val_loss: 2.2813
#
# Epoch 00010: val_loss improved from 2.34917 to 2.28127, saving model to best_model.h5
# Epoch 11/50
# 21128/21128 [==============================] - 14s 657us/step - loss: 1.9531 - val_loss: 2.1881
#
# Epoch 00011: val_loss improved from 2.28127 to 2.18815, saving model to best_model.h5
# Epoch 12/50
# 21128/21128 [==============================] - 16s 775us/step - loss: 1.8951 - val_loss: 2.1630
#
# Epoch 00012: val_loss improved from 2.18815 to 2.16305, saving model to best_model.h5
# Epoch 13/50
# 21128/21128 [==============================] - 16s 759us/step - loss: 1.8389 - val_loss: 2.1367
#
# Epoch 00013: val_loss improved from 2.16305 to 2.13671, saving model to best_model.h5
# Epoch 14/50
# 21128/21128 [==============================] - 16s 764us/step - loss: 1.8075 - val_loss: 2.0770
#
# Epoch 00014: val_loss improved from 2.13671 to 2.07701, saving model to best_model.h5
# Epoch 15/50
# 21128/21128 [==============================] - 16s 769us/step - loss: 1.7456 - val_loss: 2.0379
#
# Epoch 00015: val_loss improved from 2.07701 to 2.03795, saving model to best_model.h5
# Epoch 16/50
# 21128/21128 [==============================] - 16s 764us/step - loss: 1.6928 - val_loss: 1.9981
#
# Epoch 00016: val_loss improved from 2.03795 to 1.99814, saving model to best_model.h5
# Epoch 17/50
# 21128/21128 [==============================] - 16s 756us/step - loss: 1.6559 - val_loss: 1.9837
#
# Epoch 00017: val_loss improved from 1.99814 to 1.98365, saving model to best_model.h5
# Epoch 18/50
# 21128/21128 [==============================] - 15s 697us/step - loss: 1.6064 - val_loss: 1.9307
#
# Epoch 00018: val_loss improved from 1.98365 to 1.93068, saving model to best_model.h5
# Epoch 19/50
# 21128/21128 [==============================] - 16s 760us/step - loss: 1.5621 - val_loss: 1.8989
#
# Epoch 00019: val_loss improved from 1.93068 to 1.89893, saving model to best_model.h5
# Epoch 20/50
# 21128/21128 [==============================] - 16s 747us/step - loss: 1.5353 - val_loss: 1.8878
#
# Epoch 00020: val_loss improved from 1.89893 to 1.88775, saving model to best_model.h5
# Epoch 21/50
# 21128/21128 [==============================] - 16s 766us/step - loss: 1.5055 - val_loss: 1.8665
#
# Epoch 00021: val_loss improved from 1.88775 to 1.86647, saving model to best_model.h5
# Epoch 22/50
# 21128/21128 [==============================] - 16s 755us/step - loss: 1.4679 - val_loss: 1.8585
#
# Epoch 00022: val_loss improved from 1.86647 to 1.85854, saving model to best_model.h5
# Epoch 23/50
# 21128/21128 [==============================] - 16s 760us/step - loss: 1.4538 - val_loss: 1.8150
#
# Epoch 00023: val_loss improved from 1.85854 to 1.81499, saving model to best_model.h5
# Epoch 24/50
# 21128/21128 [==============================] - 16s 752us/step - loss: 1.3995 - val_loss: 1.7992
#
# Epoch 00024: val_loss improved from 1.81499 to 1.79918, saving model to best_model.h5
# Epoch 25/50
# 21128/21128 [==============================] - 16s 746us/step - loss: 1.3788 - val_loss: 1.7973
#
# Epoch 00025: val_loss improved from 1.79918 to 1.79726, saving model to best_model.h5
# Epoch 26/50
# 21128/21128 [==============================] - 15s 733us/step - loss: 1.3550 - val_loss: 1.7819
#
# Epoch 00026: val_loss improved from 1.79726 to 1.78189, saving model to best_model.h5
# Epoch 27/50
# 21128/21128 [==============================] - 15s 728us/step - loss: 1.3314 - val_loss: 1.7993
#
# Epoch 00027: val_loss did not improve from 1.78189
# Epoch 28/50
# 21128/21128 [==============================] - 16s 753us/step - loss: 1.3058 - val_loss: 1.7724
#
# Epoch 00028: val_loss improved from 1.78189 to 1.77239, saving model to best_model.h5
# Epoch 29/50
# 21128/21128 [==============================] - 16s 752us/step - loss: 1.2971 - val_loss: 1.7616
#
# Epoch 00029: val_loss improved from 1.77239 to 1.76156, saving model to best_model.h5
# Epoch 30/50
# 21128/21128 [==============================] - 15s 732us/step - loss: 1.2752 - val_loss: 1.7333
#
# Epoch 00030: val_loss improved from 1.76156 to 1.73326, saving model to best_model.h5
# Epoch 31/50
# 21128/21128 [==============================] - 15s 731us/step - loss: 1.2422 - val_loss: 1.7361
#
# Epoch 00031: val_loss did not improve from 1.73326
# Epoch 32/50
# 21128/21128 [==============================] - 16s 771us/step - loss: 1.2226 - val_loss: 1.7360
#
# Epoch 00032: val_loss did not improve from 1.73326
# Epoch 33/50
# 21128/21128 [==============================] - 16s 764us/step - loss: 1.2028 - val_loss: 1.7417
#
# Epoch 00033: val_loss did not improve from 1.73326
# Epoch 34/50
# 21128/21128 [==============================] - 16s 762us/step - loss: 1.1911 - val_loss: 1.7271
#
# Epoch 00034: val_loss improved from 1.73326 to 1.72709, saving model to best_model.h5
# Epoch 35/50
# 21128/21128 [==============================] - 16s 755us/step - loss: 1.1600 - val_loss: 1.7063
#
# Epoch 00035: val_loss improved from 1.72709 to 1.70633, saving model to best_model.h5
# Epoch 36/50
# 21128/21128 [==============================] - 16s 767us/step - loss: 1.1561 - val_loss: 1.7186
#
# Epoch 00036: val_loss did not improve from 1.70633
# Epoch 37/50
# 21128/21128 [==============================] - 16s 764us/step - loss: 1.1528 - val_loss: 1.7020
#
# Epoch 00037: val_loss improved from 1.70633 to 1.70200, saving model to best_model.h5
# Epoch 38/50
# 21128/21128 [==============================] - 16s 762us/step - loss: 1.1291 - val_loss: 1.7070
#
# Epoch 00038: val_loss did not improve from 1.70200
# Epoch 39/50
# 21128/21128 [==============================] - 16s 741us/step - loss: 1.1364 - val_loss: 1.7047
#
# Epoch 00039: val_loss did not improve from 1.70200
# Epoch 40/50
# 21128/21128 [==============================] - 16s 768us/step - loss: 1.1036 - val_loss: 1.7002
#
# Epoch 00040: val_loss improved from 1.70200 to 1.70016, saving model to best_model.h5
# Epoch 41/50
# 21128/21128 [==============================] - 16s 749us/step - loss: 1.0809 - val_loss: 1.6931
#
# Epoch 00041: val_loss improved from 1.70016 to 1.69314, saving model to best_model.h5
# Epoch 42/50
# 21128/21128 [==============================] - 16s 777us/step - loss: 1.0755 - val_loss: 1.6931
#
# Epoch 00042: val_loss improved from 1.69314 to 1.69312, saving model to best_model.h5
# Epoch 43/50
# 21128/21128 [==============================] - 16s 766us/step - loss: 1.0562 - val_loss: 1.6886
#
# Epoch 00043: val_loss improved from 1.69312 to 1.68855, saving model to best_model.h5
# Epoch 44/50
# 21128/21128 [==============================] - 16s 757us/step - loss: 1.0527 - val_loss: 1.6967
#
# Epoch 00044: val_loss did not improve from 1.68855
# Epoch 45/50
# 21128/21128 [==============================] - 16s 752us/step - loss: 1.0462 - val_loss: 1.6961
#
# Epoch 00045: val_loss did not improve from 1.68855
# Epoch 46/50
# 21128/21128 [==============================] - 16s 761us/step - loss: 1.0432 - val_loss: 1.7043
#
# Epoch 00046: val_loss did not improve from 1.68855
# Epoch 47/50
# 21128/21128 [==============================] - 16s 758us/step - loss: 1.0228 - val_loss: 1.6886
#
# Epoch 00047: val_loss did not improve from 1.68855
# Epoch 48/50
# 21128/21128 [==============================] - 16s 757us/step - loss: 0.9988 - val_loss: 1.6764
#
# Epoch 00048: val_loss improved from 1.68855 to 1.67636, saving model to best_model.h5
# Epoch 49/50
# 21128/21128 [==============================] - 16s 748us/step - loss: 0.9883 - val_loss: 1.6891
#
# Epoch 00049: val_loss did not improve from 1.67636
# Epoch 50/50
# 21128/21128 [==============================] - 15s 732us/step - loss: 0.9896 - val_loss: 1.6978
#
# Epoch 00050: val_loss did not improve from 1.67636

# %%
#loading best model
from keras.models import load_model
model = load_model('best_model.h5')

# %%
import random, numpy as np
indices = np.random.randint(0,len(x_val)-1,size=10)
predictions = []

for ind in indices:
    random_music = x_val[ind]
    pred = []
    for i in range(10):

        random_music = random_music.reshape(1,no_of_timesteps)

        prob = model.predict(random_music)[0]
        y_pred = np.argmax(prob,axis=0)
        pred.append(y_pred)

        random_music = np.insert(random_music[0],len(random_music[0]),y_pred)
        random_music = random_music[1:]
    predictions.append(pred)
# print(predictions)

# %%
x_int_to_note = dict((number, note_) for number, note_ in enumerate(unique_x)) 
predicted_notes = []
for i in predictions:
    temp = []
    for j in i:
        temp.append(x_int_to_note[j])
    predicted_notes.append(temp)

# %%
len(predicted_notes)
# Out:
# 10

# %%
def convert_to_midi(prediction_output, series_id):
   
    offset = 0
    output_notes = []

    # create note and chord objects based on the values generated by the model
    for pattern in prediction_output:
        
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                
                cn=int(current_note)
                new_note = note.Note(cn)
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
                
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
            
        # pattern is a note
        else:
            
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)

        # increase offset each iteration so that notes do not stack
        offset += 1
    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp='..\\music_output\\music' + str(series_id) + '.mid')

# %%
j = 1
for i in predicted_notes:
    convert_to_midi(i, j)
    j += 1
# Out:
# kok
# kok
# kok
# kok
# kok
# kok
# kok
# kok
# kok
# kok

# %%
import dill

# %%
dill.dump_session('notebook_env.db')
